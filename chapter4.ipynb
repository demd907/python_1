# %%
# 더하기
print(3 + 2)
# Out:
# 5

# %%
# 빼기
print(3-1)
# Out:
# 2

# %%
# 곱하기
print(3 * 2)
# Out:
# 6

# %%
# /
print(7 / 2)

# //
print(7 // 2)

# %
print(7 % 2)
# Out:
# 3.5
# 3
# 1

# %%
print (divmod(3, 2))
print (divmod(13, 2))
print (divmod(13, 5))
print (divmod(16, 3))
print (divmod(16, 7))
print (divmod(18, 2))
print (divmod(19, 5))


print(7//4,"." , 7%4)
# Out:
# (1, 1)
# (6, 1)
# (2, 3)
# (5, 1)
# (2, 2)
# (9, 0)
# (3, 4)
# 1 . 3
